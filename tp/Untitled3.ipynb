# %%
from all_history import * #Historys,  historySummary
import core.common_include as common_include
common_include.unittest = True

# %%
h = Historys()
# Out:
# 'G:\\My Drive\\vepar\\all_history.csv'
# 'Reading History from G:\\My Drive\\vepar\\all_history.csv'
