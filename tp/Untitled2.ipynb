# %%
from all_history import * #Historys,  historySummary
h = Historys()
# Out:
# 'G:\\My Drive\\vepar\\all_history.csv'
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[52], line 6
#       4 # from core.common_include import *
#       5 print(hist_file)
# ----> 6 h = Historys()
#
# File <string>:3, in __init__(self)
#
# File G:\My Drive\Software\PycharmProjects\tp\all_history.py:264, in Historys.__post_init__(self)
#     262 if unittest:
#     263     hist_file = rootdir + "all_history_test.csv"
# --> 264 self.readFile(self.cls, self.uniqueCols, header_lines=header_lines, datafile=hist_file)
#     265 df = self.getDF()
#     267 self.all_symbols = df[Symbol].unique()
#
# UnboundLocalError: local variable 'hist_file' referenced before assignment

# %%
from TradeUtil import *
@dataclass
class h_test(Historys):
    def __post_init__(self):
        # hist_file = rootdir + "all_history_test.csv"
        super().__post_init__()
        return

print(unittest)
unittest = True
ht = h_test()
# Out:
# False
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[46], line 11
#       9 print(unittest)
#      10 unittest = True
# ---> 11 ht = h_test()
#
# File <string>:3, in __init__(self)
#
# Cell In[46], line 6, in h_test.__post_init__(self)
#       4 def __post_init__(self):
#       5     # hist_file = rootdir + "all_history_test.csv"
# ----> 6     super().__post_init__()
#       7     return
#
# File G:\My Drive\Software\PycharmProjects\tp\all_history.py:264, in Historys.__post_init__(self)
#     262 if unittest:
#     263     hist_file = rootdir + "all_history_test.csv"
# --> 264 self.readFile(self.cls, self.uniqueCols, header_lines=header_lines, datafile=hist_file)
#     265 df = self.getDF()
#     267 self.all_symbols = df[Symbol].unique()
#
# UnboundLocalError: local variable 'hist_file' referenced before assignment

# %%
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[40], line 2
#       1 unittest = True
# ----> 2 ht = h_test()
#
# File <string>:3, in __init__(self)
#
# Cell In[38], line 6, in h_test.__post_init__(self)
#       4 def __post_init__(self):
#       5     # hist_file = rootdir + "all_history_test.csv"
# ----> 6     super().__post_init__()
#       7     return
#
# File G:\My Drive\Software\PycharmProjects\tp\all_history.py:264, in Historys.__post_init__(self)
#     262 if unittest:
#     263     hist_file = rootdir + "all_history_test.csv"
# --> 264 self.readFile(self.cls, self.uniqueCols, header_lines=header_lines, datafile=hist_file)
#     265 df = self.getDF()
#     267 self.all_symbols = df[Symbol].unique()
#
# UnboundLocalError: local variable 'hist_file' referenced before assignment

# %%
import importlib

# First, set unittest flag before importing the class
unittest = True

# Import the class and reload the module
import MyClass
importlib.reload(MyClass)

# Create an instance of MyClass
obj = MyClass.MyClass(10)
obj.display()  # This should print "Unittest in progress" if unittest is True
# Out:
# Value: 10
